# %%
import numpy as np
import pandas as pd
from Decision_Tree import DecisionTreeReg
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# %%
data = pd.read_csv("data.csv")
data
# Out:
#            X         y
# 0   0.093949  0.639861
# 1   0.101092  0.100920
# 2   0.195939  0.194688
# 3   0.301127  0.296597
# 4   0.355180  0.347759
# ..       ...       ...
# 75  4.818314 -0.043969
# 76  4.882297 -0.985600
# 77  4.883805 -0.985344
# 78  4.893092 -0.983718
# 79  4.941869 -0.973785
#
# [80 rows x 2 columns]

# %%
X = data.drop("y", axis = 1).values
y = data["y"].values

# %%
model = DecisionTreeReg(max_depth=15)    # overfitting
model.fit(X,y)

# %%
y_pred = model.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred,c = "r")

# %%
model = DecisionTreeRegressor()
model.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X)
plt.scatter(X,y)
plt.plot(X,y_pred,c = "r")
