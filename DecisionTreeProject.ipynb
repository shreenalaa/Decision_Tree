# %% [markdown]
# ✨ Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Decision_Tree import DecisionTreeCla
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ✨ Loading Data

# %%
data = pd.read_csv("iris_data.csv")
data
# Out:
#      feature1  feature2  target
# 0         5.1       3.5     0.0
# 1         4.9       3.0     0.0
# 2         4.7       3.2     0.0
# 3         4.6       3.1     0.0
# 4         5.0       3.6     0.0
# ..        ...       ...     ...
# 145       6.7       3.0     1.0
# 146       6.3       2.5     1.0
# 147       6.5       3.0     1.0
# 148       6.2       3.4     1.0
# 149       5.9       3.0     1.0
#
# [150 rows x 3 columns]

# %% [markdown]
# ✨ Split Data ( x, y)

# %%
X = data.drop("target", axis = 1).values
y = data["target"].values.astype("int32")

# %% [markdown]
# ✨ Build Model From Skratch

# %%
model = DecisionTree(max_depth=3,criterion="gini")
model.fit(X,y)

# %% [markdown]
# ✨ Visualization

# %%
plt.scatter(X[:,0],X[:,1],c = y)
x1_min, x1_max = X[:,0].min()-1 , X[:,0].max()+1
x2_min, x2_max = X[:,1].min()-1 , X[:,1].max()+1
xx1, xx2 = np.meshgrid(
    np.arange(x1_min,x1_max,.1),
    np.arange(x2_min,x2_max,.1)
)
meshgred_points = np.array([xx1.ravel(),xx2.ravel()]).T
z = model.predict(meshgred_points)
z = z.reshape(xx1.shape)
plt.contourf(xx1, xx2, z,alpha = .2)

# %% [markdown]
# ✨ Use Built in Model From Sklearn

# %%
model = DecisionTreeClassifier(max_depth = 3)
model.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ✨ Visualization

# %%
plt.scatter(X[:,0],X[:,1],c = y)
x1_min, x1_max = X[:,0].min()-1 , X[:,0].max()+1
x2_min, x2_max = X[:,1].min()-1 , X[:,1].max()+1
xx1, xx2 = np.meshgrid(
    np.arange(x1_min,x1_max,.1),
    np.arange(x2_min,x2_max,.1)
)
meshgred_points = np.array([xx1.ravel(),xx2.ravel()]).T
z = model.predict(meshgred_points)
z = z.reshape(xx1.shape)
plt.contourf(xx1, xx2, z,alpha = .2)
